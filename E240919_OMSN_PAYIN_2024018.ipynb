# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import csv
import os
warnings.filterwarnings('ignore')
from datetime import datetime

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
directory = r'D:\RECONCILIATIONS\PAIEMENT\OM SENEGAL\Données PMT\2024\SEPT'

# Trouver le fichier CSV le plus récent dans le répertoire
def get_latest_file(directory):
    files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.csv')]
    latest_file = max(files, key=os.path.getctime)
    return latest_file

# Charger le fichier CSV le plus récent
latest_file_path = get_latest_file(directory)
pmt = pd.read_csv(latest_file_path)

pmt.sample()


directory = r'D:\RECONCILIATIONS\PAIEMENT\OM SENEGAL\Données OP\2024\SEPT'

# Trouver le fichier le plus récent dans le répertoire
def get_latest_file(directory):
    files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.xlsx')]
    latest_file = max(files, key=os.path.getctime)
    return latest_file

# Charger le fichier le plus récent
latest_file_path = get_latest_file(directory)
op = pd.read_excel(latest_file_path)

# %%
op.head(2)
# Out:
#          Date     Heure             Référence           Service     Paiement  \
# 0  18/09/2024  00:00:00  MP240918.0000.B13191  Merchant Payment  Transaction
# 1  18/09/2024  00:00:01  MP240918.0000.C13158  Merchant Payment  Transaction
#
#    Statut  Mode  N° de Compte  Wallet  N° Pseudo N° de Compte.1 Wallet.1  \
# 0  Succès  USSD     771507459  Normal        NaN      777547455   Normal
# 1  Succès  USSD     771507459  Normal        NaN      775475252   Normal
#
#    Débit  Crédit  Compte: 771507459  Sous-réseau
# 0    NaN 3000.00             -30.00            0
# 1    NaN 1000.00             -10.00            0

# %%
#op = pd.read_excel(r'D:\RECONCILIATIONS\PAIEMENT\OM SENEGAL\Données OP\2024\JUIN\20240701_paiment_OM_SN_20240601_20240630.xlsx')

# %%
#pmt = pd.read_csv(r'D:\RECONCILIATIONS\PAIEMENT\OM SENEGAL\Données PMT\2024\JUIN\E20240701-Pmt-Payment-OM-SN-20240601_20240630.csv')

# %%
#SAUVEGARDER UNE COPIE DE LA DATAFRAME
op1=op.copy()
pmt1=pmt.copy()

# %%
dfpmt = pmt.rename(columns={
        'created_at': 'Created Date',
        'payment_date': 'Payment Date',
        'operator': 'Operator',
        'merchant_name': 'Merchant Name',
        'transaction_id': 'Transaction ID',
        'id_operator': 'ID Opérateur',
        'phone_number': 'Phone Number',
        'amount': 'Montant',
        'fee_amount': 'Fee amount',
        'merchant_amount': 'Merchant amount',
        'statut': 'Statut'
    })
dfpmt1=dfpmt[['Created Date',
         'Payment Date',
         'Operator',
         'Merchant Name',
         'Transaction ID',
         'ID Opérateur',
         'Phone Number',
         'Montant',
         'Fee amount',
         'Merchant amount',
         'Statut'
]]

# %%
dfop=op[['Date',
         'Heure',
         'Référence',
         'Service',
         'Statut',
         'N° de Compte.1',
         'Débit',
         'Crédit',
         'Compte: 771507459'
]]

# %%
dfpmt.head(2)
# Out:
#           Created Date         Payment Date Operator      Merchant Name  \
# 0  2024-09-17 16:42:58  2024-09-17 16:42:59    OM_SN  VIKHREDA SUARL SN
# 1  2024-09-18 03:26:52                  NaN    OM_SN      Bet Winner SN
#
#                      Transaction ID  merchant_transaction_id  \
# 0  6f53953c143e47f2bcb7e95dbd8d131e              12690025257
# 1  de891426a9134c948f9ae6a4793b51b0                138586603
#
#            ID Opérateur  external_transaction_id  Phone Number  \
# 0  MP240917.1642.B27008                      NaN  221785675059
# 1                   NaN                      NaN  221788752725
#
#           client_email  Montant  Fee amount  Merchant amount operation_origin  \
# 0   elkeita7@gmail.com   500.00       20.00           480.00          payment
# 1  kaho95106@gmail.com  3300.00      198.00          3102.00          payment
#
#   currency   Statut country                provider_id provider_name
# 0      XOF  SUCCESS      SN  @@@@@MP240917.1642.B27008         OM_SN
# 1      XOF   FAILED      SN                        NaN         OM_SN

# %%
dfop.head(2)
# Out:
#          Date     Heure             Référence           Service  Statut  \
# 0  18/09/2024  00:00:00  MP240918.0000.B13191  Merchant Payment  Succès
# 1  18/09/2024  00:00:01  MP240918.0000.C13158  Merchant Payment  Succès
#
#   N° de Compte.1  Débit  Crédit  Compte: 771507459
# 0      777547455    NaN 3000.00             -30.00
# 1      775475252    NaN 1000.00             -10.00

# %%
#CONVERTIR LA DATE EN DATETIME

#EXTRAITRE LA DATE DANS UNE NOUVELLE COLLONNE
dfpmt['DateCourte'] = dfpmt['Created Date'].apply(lambda x: x.split(' ')[0])

# %% [markdown]
# VERIFACTION DES DOUBLONS

# %%
dfop['Référence'].isnull().sum()
# Out:
# 0

# %%
dfpmt['Transaction ID'].isnull().sum()
# Out:
# 0

# %%
dfop['Idpmt'] = dfop['Référence']

# %%
dfop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59485 entries, 0 to 59484
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               59485 non-null  object
#  1   Heure              59485 non-null  object
#  2   Référence          59485 non-null  object
#  3   Service            59485 non-null  object
#  4   Statut             59485 non-null  object
#  5   N° de Compte.1     59485 non-null  object
#  6   Débit              888 non-null    float64
#  7   Crédit             58597 non-null  float64
#  8   Compte: 771507459  59485 non-null  float64
#  9   Idpmt              59485 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 4.5+ MB

# %% [markdown]
# MISE EN PLACE DE RECHERCHE X POUR RECUPERATION CHEZ L'OP
# Vérification des correspondances entre A1 et B1

# %%
correspondance_statut_op= dfop.set_index('Référence')['Statut']
correspondance_date_op = dfop.set_index('Référence')['Date']
correspondance_idoperator = dfop.set_index('Référence')['Idpmt']


dfpmt['DATEOP'] = dfpmt['ID Opérateur'].map(correspondance_date_op)
dfpmt['STATUTOP'] = dfpmt['ID Opérateur'].map(correspondance_statut_op)
dfpmt['IDOPERATOR'] = dfpmt['ID Opérateur'].map(correspondance_idoperator)

# %%
dfpmt['DATEOP'].unique()
# Out:
# array([nan, '18/09/2024'], dtype=object)

# %% [markdown]
# CALCUL DES TAUX ET FRAIS

# %%
dfpmt['Fraisop'] = dfpmt['Montant'] * 0.001
dfpmt['FraisPmt'] = dfpmt['Fee amount'] - dfpmt['Fraisop']

# %% [markdown]
# NBSI PMT ET ORANGE SN

# %%
payin= dfop.loc[(dfop['Service'] == 'Merchant Payment')]

# %%
#NBSI PMT &OMBF
dfpmt['OMSN'] = dfpmt['ID Opérateur'].isin(payin['Référence']).astype(int)
payin['PMT'] = payin['Référence'].isin(dfpmt['ID Opérateur']).astype(int)

# %%
dfpmt['Nombre']= dfpmt['Montant']
payin['Nombre']= payin['Crédit']

# %% [markdown]
# TABLEAU CROISE DYNAMIQUE

# %%
df_filteredpmt = dfpmt[dfpmt['OMSN'] == 1]

# Création du tableau croisé dynamique
tcdpmt = pd.pivot_table(
    df_filteredpmt,
    values=['Montant', 'Nombre','Fraisop', 'FraisPmt'],
    index=['DATEOP','Statut'],
    aggfunc={'Nombre': 'count','Montant': 'sum' ,'Fraisop': 'sum', 'FraisPmt': 'sum' },
    fill_value=0,
    margins=True,
    margins_name='Total'
)

df_filtered = payin[(payin['PMT'] == 1) | (payin['PMT'] == 0)]

# Création du tableau croisé dynamique
tcdomsn = pd.pivot_table(
    df_filtered,
    values=['Nombre', 'Crédit'],
    index=['Date','Statut'],
    aggfunc={'Nombre': 'count','Crédit': 'sum' },
    fill_value=0,
    margins=True,
    margins_name='Total'
)

# %%
tcdomsn
# Out:
#                         Crédit  Nombre
# Date       Statut
# 18/09/2024 Succès 275455090.00   58597
# Total             275455090.00   58597

# %%
tcdpmt
# Out:
#                      FraisPmt   Fraisop      Montant  Nombre
# DATEOP     Statut
# 18/09/2024 SUCCESS 9394299.64 275455.09 275455090.00   58597
# Total              9394299.64 275455.09 275455090.00   58597

# %%
maj1 = dfpmt.loc[(dfpmt['Statut'] == 'FAILED') & (dfpmt['OMSN'] == 1)]
maj2 = dfpmt.loc[(dfpmt['Statut'] == 'PENDING') & (dfpmt['OMSN'] == 1)]

# %%
maj1
# Out:
# Empty DataFrame
# Columns: [Created Date, Payment Date, Operator, Merchant Name, Transaction ID, merchant_transaction_id, ID Opérateur, external_transaction_id, Phone Number, client_email, Montant, Fee amount, Merchant amount, operation_origin, currency, Statut, country, provider_id, provider_name, DateCourte, DATEOP, STATUTOP, IDOPERATOR, Fraisop, FraisPmt, OMSN, Nombre]
# Index: []
#
# [0 rows x 27 columns]

# %%
maj2
# Out:
# Empty DataFrame
# Columns: [Created Date, Payment Date, Operator, Merchant Name, Transaction ID, merchant_transaction_id, ID Opérateur, external_transaction_id, Phone Number, client_email, Montant, Fee amount, Merchant amount, operation_origin, currency, Statut, country, provider_id, provider_name, DateCourte, DATEOP, STATUTOP, IDOPERATOR, Fraisop, FraisPmt, OMSN, Nombre]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# TRANSACTION SUCCES A RECHERCHER

# %%
trx_succes_a_rechercher = payin.loc[(payin['PMT'] == 0)]
trx_succes_a_rechercher
# Out:
# Empty DataFrame
# Columns: [Date, Heure, Référence, Service, Statut, N° de Compte.1, Débit, Crédit, Compte: 771507459, Idpmt, PMT, Nombre]
# Index: []

# %%
trx_a_rech = dfpmt.loc[(dfpmt['Phone Number'] == 221774116189)]
trx_a_rech
# Out:
#                Created Date         Payment Date Operator  \
# 58564   2024-09-18 16:14:13  2024-09-18 16:14:15    OM_SN
# 76925   2024-09-17 13:44:28  2024-09-17 13:44:30    OM_SN
# 77140   2024-09-17 13:47:41  2024-09-17 13:47:43    OM_SN
# 90651   2024-09-17 17:02:37  2024-09-17 17:02:39    OM_SN
# 121010  2024-09-17 01:58:58  2024-09-17 01:59:00    OM_SN
# 122521  2024-09-17 01:43:53  2024-09-17 01:43:54    OM_SN
#
#                        Merchant Name                    Transaction ID  \
# 58564   Service Online International  85ac3fb42b3c4b2694199da465e5c0dc
# 76925   Service Online International  6288dbec68be4b94b0904366844a1f5d
# 77140   Service Online International  9e41cc89568247209c42645cc4551764
# 90651   Service Online International  c7ca6e0e9a284451b6a01cc0c037b9f2
# 121010  Service Online International  6a08986df91e4d2498461f6e7f01c24e
# 122521  Service Online International  26d076ba8f254d30b5b24340fcb8045f
#
#         merchant_transaction_id          ID Opérateur  \
# 58564               12705031529  MP240918.1614.A11860
# 76925               12686792051  MP240917.1344.C91564
# 77140               12686844729  MP240917.1347.A97277
# 90651               12690384157  MP240917.1702.D31348
# 121010              12680861923  MP240917.0158.A35070
# 122521              12680807691  MP240917.0143.D29880
#
#         external_transaction_id  Phone Number               client_email  ...  \
# 58564                       NaN  221774116189  fallilou.kamara@gmail.com  ...
# 76925                       NaN  221774116189  fallilou.kamara@gmail.com  ...
# 77140                       NaN  221774116189  fallilou.kamara@gmail.com  ...
# 90651                       NaN  221774116189  fallilou.kamara@gmail.com  ...
# 121010                      NaN  221774116189  fallilou.kamara@gmail.com  ...
# 122521                      NaN  221774116189  fallilou.kamara@gmail.com  ...
#
#                       provider_id  provider_name  DateCourte      DATEOP  \
# 58564   @@@@@MP240918.1614.A11860          OM_SN  2024-09-18  18/09/2024
# 76925   @@@@@MP240917.1344.C91564          OM_SN  2024-09-17         NaN
# 77140   @@@@@MP240917.1347.A97277          OM_SN  2024-09-17         NaN
# 90651   @@@@@MP240917.1702.D31348          OM_SN  2024-09-17         NaN
# 121010  @@@@@MP240917.0158.A35070          OM_SN  2024-09-17         NaN
# 122521  @@@@@MP240917.0143.D29880          OM_SN  2024-09-17         NaN
#
#        STATUTOP            IDOPERATOR Fraisop FraisPmt OMSN   Nombre
# 58564    Succès  MP240918.1614.A11860   10.00   340.00    1 10000.00
# 76925       NaN                   NaN    1.50    51.00    0  1500.00
# 77140       NaN                   NaN    3.50   119.00    0  3500.00
# 90651       NaN                   NaN    2.00    68.00    0  2000.00
# 121010      NaN                   NaN    2.00    68.00    0  2000.00
# 122521      NaN                   NaN    1.00    34.00    0  1000.00
#
# [6 rows x 27 columns]

# %%
trx_succes_abs_omsn = dfpmt.loc[(dfpmt['OMSN'] == 0) & (dfpmt['Statut'] == 'SUCCESS')]
trx_succes_abs_omsn
# Out:
#                Created Date         Payment Date Operator      Merchant Name  \
# 0       2024-09-17 16:42:58  2024-09-17 16:42:59    OM_SN  VIKHREDA SUARL SN
# 6       2024-09-17 12:06:54  2024-09-17 12:06:56    OM_SN  VIKHREDA SUARL SN
# 9       2024-09-17 12:09:40  2024-09-17 12:09:43    OM_SN  VIKHREDA SUARL SN
# 30      2024-09-17 12:16:27  2024-09-17 12:16:28    OM_SN  VIKHREDA SUARL SN
# 37      2024-09-17 12:17:48  2024-09-17 12:17:49    OM_SN  VIKHREDA SUARL SN
# ...                     ...                  ...      ...                ...
# 137388  2024-09-17 23:24:55  2024-09-17 23:24:56    OM_SN  VIKHREDA SUARL SN
# 137390  2024-09-17 23:37:52  2024-09-17 23:37:53    OM_SN  VIKHREDA SUARL SN
# 137394  2024-09-17 11:54:34  2024-09-17 11:54:35    OM_SN  VIKHREDA SUARL SN
# 137408  2024-09-17 12:04:54  2024-09-17 12:04:55    OM_SN  VIKHREDA SUARL SN
# 137412  2024-09-17 16:39:31  2024-09-17 16:39:33    OM_SN  VIKHREDA SUARL SN
#
#                           Transaction ID  merchant_transaction_id  \
# 0       6f53953c143e47f2bcb7e95dbd8d131e              12690025257
# 6       4691690698c44eb7ba10d82ae6f7e9a5              12685298313
# 9       b0c821d715f247dcad0065391d92d0bb              12685337667
# 30      50d740ea4c7a47b38c11d23b268f3c90              12685434883
# 37      bd4cd71912d1485388b7a2f881e7e64d              12685454481
# ...                                  ...                      ...
# 137388  88420a4873d84f7caecdee1ae2336c12              12695730019
# 137390  761f62b16d6048de928deb2d9c7a27be              12695817015
# 137394  ef0a9e0b04184cf6a89726cbd6130285              12685116453
# 137408  85242f7667f24603b5562d0ba27acc4f              12685268841
# 137412  2542eb30f6d94403b927c23f57016159              12689955093
#
#                 ID Opérateur  external_transaction_id  Phone Number  \
# 0       MP240917.1642.B27008                      NaN  221785675059
# 6       MP240917.1206.B70643                      NaN  221772825068
# 9       MP240917.1209.D72107                      NaN  221786069851
# 30      MP240917.1216.B72664                      NaN  221771231267
# 37      MP240917.1217.D73828                      NaN  221776609289
# ...                      ...                      ...           ...
# 137388  MP240917.2324.A13792                      NaN  221783916628
# 137390  MP240917.2337.D11012                      NaN  221777441324
# 137394  MP240917.1154.C68201                      NaN  221788336455
# 137408  MP240917.1204.D71105                      NaN  221783269145
# 137412  MP240917.1639.D26996                      NaN  221773062813
#
#                            client_email  ...                provider_id  \
# 0                    elkeita7@gmail.com  ...  @@@@@MP240917.1642.B27008
# 6                Sirabalde709@gmail.com  ...  @@@@@MP240917.1206.B70643
# 9              Sack2022amadou@gmail.com  ...  @@@@@MP240917.1209.D72107
# 30           rogericbonadiene@gmail.com  ...  @@@@@MP240917.1216.B72664
# 37                  fmandiame@gmail.com  ...  @@@@@MP240917.1217.D73828
# ...                                 ...  ...                        ...
# 137388            Ciresow1996@gmail.com  ...  @@@@@MP240917.2324.A13792
# 137390              gakouboyz@gmail.com  ...  @@@@@MP240917.2337.D11012
# 137394         maremenyafouna@gmail.com  ...  @@@@@MP240917.1154.C68201
# 137408  Mamadoulaminedanfa57@icloud.com  ...  @@@@@MP240917.1204.D71105
# 137412           Iboufaye1988@gmail.com  ...  @@@@@MP240917.1639.D26996
#
#         provider_name  DateCourte DATEOP STATUTOP IDOPERATOR Fraisop FraisPmt  \
# 0               OM_SN  2024-09-17    NaN      NaN        NaN    0.50    19.50
# 6               OM_SN  2024-09-17    NaN      NaN        NaN    0.50    19.50
# 9               OM_SN  2024-09-17    NaN      NaN        NaN    1.00    39.00
# 30              OM_SN  2024-09-17    NaN      NaN        NaN    0.90    35.10
# 37              OM_SN  2024-09-17    NaN      NaN        NaN    0.50    19.50
# ...               ...         ...    ...      ...        ...     ...      ...
# 137388          OM_SN  2024-09-17    NaN      NaN        NaN    2.00    78.00
# 137390          OM_SN  2024-09-17    NaN      NaN        NaN    2.00    78.00
# 137394          OM_SN  2024-09-17    NaN      NaN        NaN    1.00    39.00
# 137408          OM_SN  2024-09-17    NaN      NaN        NaN    0.75    29.25
# 137412          OM_SN  2024-09-17    NaN      NaN        NaN    1.80    70.20
#
#        OMSN  Nombre
# 0         0  500.00
# 6         0  500.00
# 9         0 1000.00
# 30        0  900.00
# 37        0  500.00
# ...     ...     ...
# 137388    0 2000.00
# 137390    0 2000.00
# 137394    0 1000.00
# 137408    0  750.00
# 137412    0 1800.00
#
# [68064 rows x 27 columns]

# %%
 # Enregistrer les données filtrées dans un fichier Excel

# Enregistrer les données filtrées dans un fichier Excel

#output_file_path = 'D:/RECO/OMSN/PAYIN/MAJ/trx_a_mettre_ajour.xlsx'
#maj.to_excel(output_file_path, index=False)

#print(f"Fichier enregistré sous : {output_file_path}")

# %%
# Date spécifique du rapport
report_date = "20240918"

# Générer automatiquement le chemin de sortie avec la date actuelle
current_date = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = 'D:/RECO/OMSN/PAYIN/RECAPANALYSE/SEPT'
output_file_name = f"{current_date}_RAPPORT_ANALYSE_{report_date}.xlsx"
output_file_path = os.path.join(output_dir, output_file_name)

# Création de DataFrames d'exemple
data_pmt = dfpmt
data_op = payin
maj_jour_failed = maj1
maj_jour_pending = maj2
trx_succes_pmt_abs_omsn = trx_succes_abs_omsn
trx_succs_omsn_abs_pmt = trx_succes_a_rechercher

# Dictionnaire de DataFrames
feuilles = {
    'DATA PMT': data_pmt,
    'data op': data_op,
    'TRX SUCCES PMT ABS OMSN': trx_succes_pmt_abs_omsn,
    'MAJ PENDING EN SUCCES': maj_jour_pending,
    'MAJ FAILED EN SUCCES': maj_jour_failed,
    'TRX A RECHERCHER': trx_succs_omsn_abs_pmt
}

# Création de l'objet ExcelWriter
with pd.ExcelWriter(output_file_path, engine='openpyxl') as writer:
    for nom_feuille, df in feuilles.items():
        df.to_excel(writer, sheet_name=nom_feuille, index=False)

print(f"Fichier Excel avec plusieurs feuilles sauvegardé avec succès: {output_file_path}")
# Out:
# Fichier Excel avec plusieurs feuilles sauvegardé avec succès: D:/RECO/OMSN/PAYIN/RECAPANALYSE/SEPT\20240919_092013_RAPPORT_ANALYSE_20240918.xlsx

# %% [markdown]
# ANALYSE PMT

# %%
succes= dfpmt[(dfpmt['Statut'] == 'SUCCESS')]
echec =dfpmt[(dfpmt['Statut'] == 'FAILED')]

# %%
success=succes[['Created Date',
           'Payment Date',
           'Operator',
           'Merchant Name',
           'Transaction ID',
           'Phone Number',
           'DateCourte',
           'DATEOP',
           'Statut',
           'STATUTOP',
           'Montant'
]]
success.head(2)
# Out:
#           Created Date         Payment Date Operator      Merchant Name  \
# 0  2024-09-17 16:42:58  2024-09-17 16:42:59    OM_SN  VIKHREDA SUARL SN
# 6  2024-09-17 12:06:54  2024-09-17 12:06:56    OM_SN  VIKHREDA SUARL SN
#
#                      Transaction ID  Phone Number  DateCourte DATEOP   Statut  \
# 0  6f53953c143e47f2bcb7e95dbd8d131e  221785675059  2024-09-17    NaN  SUCCESS
# 6  4691690698c44eb7ba10d82ae6f7e9a5  221772825068  2024-09-17    NaN  SUCCESS
#
#   STATUTOP  Montant
# 0      NaN   500.00
# 6      NaN   500.00

# %%
echecs=echec[['Created Date',
           'Payment Date',
           'Operator',
           'Merchant Name',
           'Transaction ID',
           'Phone Number',
           'DateCourte',
           'DATEOP',
           'Statut',
           'STATUTOP',
           'Montant'
]]
echecs.head(2)
# Out:
#           Created Date Payment Date Operator      Merchant Name  \
# 1  2024-09-18 03:26:52          NaN    OM_SN      Bet Winner SN
# 2  2024-09-18 03:26:55          NaN    OM_SN  VIKHREDA SUARL SN
#
#                      Transaction ID  Phone Number  DateCourte DATEOP  Statut  \
# 1  de891426a9134c948f9ae6a4793b51b0  221788752725  2024-09-18    NaN  FAILED
# 2  b6f45a0076ea418eaa7b0fb57a0a8b61  221779660699  2024-09-18    NaN  FAILED
#
#   STATUTOP  Montant
# 1      NaN  3300.00
# 2      NaN  3000.00

# %%
select_success_min = success.groupby(['DateCourte','STATUTOP'])['Montant'].min()
select_success_min.reset_index()
# Out:
#    DateCourte STATUTOP  Montant
# 0  2024-09-17   Succès  3000.00
# 1  2024-09-18   Succès   197.00

# %%
select_success_max = success.groupby(['DateCourte','STATUTOP'])['Montant'].max()
select_success_max.reset_index()
# Out:
#    DateCourte STATUTOP    Montant
# 0  2024-09-17   Succès    3000.00
# 1  2024-09-18   Succès 1500000.00

# %%
select_echec_min = echecs.groupby('DateCourte')['Montant'].min()
select_echec_min.reset_index()
# Out:
#    DateCourte  Montant
# 0  2024-09-17   200.00
# 1  2024-09-18   200.00
# 2  2024-09-19   200.00

# %%
select_echec_max = echecs.groupby('DateCourte')['Montant'].max()
select_echec_max.reset_index()
# Out:
#    DateCourte    Montant
# 0  2024-09-17 1500000.00
# 1  2024-09-18 1300000.00
# 2  2024-09-19 1441414.00

# %%
dfop.Service.unique()
# Out:
# array(['Merchant Payment', 'Cash in', 'Operator Withdraw'], dtype=object)

# %%
recouvrement = dfop.loc[(dfop['Service']=='Operator Withdraw')]
recouvrement
# Out:
#              Date     Heure             Référence            Service  Statut  \
# 21897  18/09/2024  14:08:14  OW240918.1231.B04542  Operator Withdraw  Succès
#
#       N° de Compte.1       Débit  Crédit  Compte: 771507459  \
# 21897          IND01 60000000.00     NaN               0.00
#
#                       Idpmt
# 21897  OW240918.1231.B04542

# %%
appro = dfop.loc[(dfop['Service']=='O2C Transfer')]
appro
# Out:
# Empty DataFrame
# Columns: [Date, Heure, Référence, Service, Statut, N° de Compte.1, Débit, Crédit, Compte: 771507459, Idpmt]
# Index: []

# %%
select_marchd = df_filteredpmt.groupby('Merchant Name').agg(
    Nombre=('Montant', 'count'),
    Montant=('Montant', 'sum')
)
select_marchd
# Out:
#                               Nombre      Montant
# Merchant Name
# Bet Winner SN                     91    473999.00
# Service Online International   57534 271585769.00
# VIKHREDA SUARL SN                972   3395322.00
